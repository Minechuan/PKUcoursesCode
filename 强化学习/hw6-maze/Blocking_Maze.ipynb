# %%
#######################################################################
# Copyright (C)                                                       #
# 2016-2018 Shangtong Zhang(zhangshangtong.cpp@gmail.com)             #
# 2016 Kenta Shimada(hyperkentakun@gmail.com)                         #
# Permission given to modify the code as long as you keep this        #
# declaration at the top                                              #
#######################################################################

# %% [markdown]
# 這次的範例主要參考[ShangtongZhang](https://github.com/ShangtongZhang/reinforcement-learning-an-introduction/blob/master/chapter07/random_walk.py)

# %% [markdown]
# Chapter 8主要結合planning與learning，讓過往的經驗可以再次得到一次利用

# %% [markdown]
# Example 8.2: Blocking Maze
#
# Figure 8.4說明了一個相對較小的模型誤差(modeling error)並且從中恢復。最一開始障礙的右邊會有一個從開始到目標的短徑(short path)，如圖左上所示。然後在1000個time steps之後，這條短徑被河蟹了，你變成要從障礙物的左邊缺點去走這條更長的路徑，如圖右上所示。
#
# ![](https://i.imgur.com/pj7Yt2F.png)
# Figure 8.4：Dyna agents在blocking task的平均效能。左圖是前1000個steps，右圖是剩下的steps。Dyna-Q+是鼓勵探索版本的Dyna-Q，有著探索獎勵。
#
# Figure 8.4說明著Dyna-Q agent與Dyna-Q+ agent(後面就會說到)的average cumulative reward。第一個部份說明的是，兩個Dyna agents在1000個steps內找到最短路徑。當環境(environment)改變的時候，你會發現有一小段的average cumulative reward變的平坦，因為它們卡到了，在障礙物後面一直走來走去的。不過一段時間之後也可以看的到，它們又找到新的開口以及新的optimal behvaior。當環境變的比之前更好的時候，而先前正確的策略(policy)卻沒有顯示出有任何改善，就會出現更大的困難。這種情況下，modeling error會有很長的一段時間無法被偵測到(如果有的話)。

# %% [markdown]
# 首先載入需求套件

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import heapq
from copy import deepcopy

# %% [markdown]
# 首先設置Environment，要注意一下這邊的一些設置是跟Example 8.1不一樣的

# %%
class Maze:
    def __init__(self):
        """初始化環境
        
        根據範例說明：
        1. 這是一個寬9高6的gridworld
        2. 每個episode的start state都是[5, 3]
        3. goal state為[0, 8]
        4. 我們能做的action就是上下左右
        5. 路面上是有障礙
        6. 在1000個step之後障礙就會變動
        """
        self.WORLD_WIDTH = 9
        self.WORLD_HEIGHT = 6
        
        self.START_STATE = [5, 3]
        self.GOAL_STATE = [0, 8]
        
        self.ACTION_UP = 0
        self.ACTION_DOWN = 1
        self.ACTION_LEFT = 2
        self.ACTION_RIGHT = 3
        self.action_space = [self.ACTION_UP, self.ACTION_DOWN, self.ACTION_LEFT, self.ACTION_RIGHT]
        
        # 障礙設置
        # 這次的範例中，障礙是會變動的
        self.obstacles = None
        self.old_obstacles = [[3, i] for i in range(0, 8)]
        self.new_obstacles = [[3, i] for i in range(1, 9)]
        
        self.value_size = (self.WORLD_HEIGHT, self.WORLD_WIDTH, len(self.action_space))
        
        # 根據範例的圖片來設置
        self.max_steps = 3000
        
        # 1000個step之後環境變換
        self.time_to_switch = 1000
        
    def step(self, state, action):
        """run step according action
        
        state: 當前的狀態
        action: 要執行的action
        
        幾點要注意：
            1. 不能超出邊界，這可以用max、min來處理
            2. 撞到障礙就是停在原地
            3. 每次的reward都是0，除非你到達goal state
            
        return next_state, reward
        """
        x, y = state
        
        if action == self.ACTION_UP:
            x = max(x - 1, 0)
        elif  action == self.ACTION_DOWN:
            x = min(x + 1, self.WORLD_HEIGHT - 1)
        elif  action == self.ACTION_LEFT:
            y = max(y - 1, 0)
        elif  action == self.ACTION_RIGHT:
            y = min(y + 1, self.WORLD_WIDTH - 1)
        
        if [x, y] in self.obstacles:
            x, y = state
        
        if [x, y] == self.GOAL_STATE:
            reward = 1.0
        else:
            reward = 0.0
        
        return [x, y], reward

# %%
maze = Maze()
maze.obstacles = maze.old_obstacles
assert maze.START_STATE == [5, 3]
assert maze.GOAL_STATE == [0, 8]
assert (maze.step([5, 3], 0)) == ([4, 3], 0)

# %% [markdown]
# 我們會需要一個model來記錄曾經有過的經驗，這個model是for Dyna-Q的

# %%
class TrivialModel:
    def __init__(self, rand=np.random):
        # 用dict來做模型，反正我們只會記錄該state-action pair最後一次的經驗
        self.model = dict()
        self.rand = rand
#         self.rand.seed(10)
    
    def feed(self, state, action, next_state, reward):
        """記錄經驗"""
        state = deepcopy(state)
        next_state = deepcopy(next_state)
        
        # 判斷該組state是否存在目前的model
        # 如不存在就賦予一個預設值
        if tuple(state) not in self.model.keys():
            self.model[tuple(state)] = dict()
        self.model[tuple(state)][action] = [list(next_state), reward]
        
    def sample(self):
        """隨機取一筆經驗出來"""
        state_index = self.rand.choice(range(len(self.model.keys())))
        state = list(self.model)[state_index]
        action_index = self.rand.choice(range(len(self.model[state].keys())))
        action = list(self.model[state])[action_index]
        next_state, reward = self.model[state][action]
        state = deepcopy(state)
        next_state = deepcopy(next_state)
        return list(state), action, list(next_state), reward

# %% [markdown]
# 我們需要另一個model來滿足Dyna-Q+的需求

# %%
class TimeModel:
    def __init__(self, maze, time_weight=1e-4, rand=np.random):
        """
        maze: Maze object
        time_weight: 時間所賦予的權重
        rand: numpy random function
        """
        self.rand = rand
        self.model = dict()
        # 追蹤記錄total time
        self.time = 0
        self.time_weight = time_weight
        self.maze = maze
        
    def feed(self, state, action, next_state, reward):
        """記錄經驗
        
        我們需要先判斷一下相關經驗是否已經存在，不存在就先設置初始格式再寫入
        剩下這個state沒有被執行過的action我們就另外做個記錄
        只是記錄的next state會是current state        
        """
        state = deepcopy(state)
        next_state = deepcopy(next_state)
        
        self.time +=1
        
        if tuple(state) not in self.model.keys():
            self.model[tuple(state)] = dict()
            
            for _action in self.maze.action_space:
                if _action != action:
                    # 這邊要注意，next_state記錄的是current state
                    # 意思就是，當我們後面去遇到這個state-action pair的時候
                    # 我們就會從current state再往下走，而不會真正的轉至下一個state
                    # 當這個pair第一次被sample到的時候，雖然reward是0，但是還是會有一個bouns reward
                    # 這也合理，沒走過的你也不知道走了以後會怎麼樣，但是它逐漸的累積之後
                    # 總是有機會被選到，那就能真正的知道它的下一個狀態是怎麼了
                    self.model[tuple(state)][_action] =[list(state), 0, 1]
        
        self.model[tuple(state)][action] = [list(next_state), reward, self.time]
    
    def sample(self):
        """隨機取一筆經驗出來"""
        state_index = self.rand.choice(range(len(self.model.keys())))
        state  = list(self.model)[state_index]
        
        action_index = self.rand.choice(range(len(self.model[state].keys())))
        action = list(self.model[state])[action_index]
        
        # 這邊我們假設我們真的去sample到那個沒被選過的pair
        # next_state還會是state
        # 然後這個pair已經好久沒有出現，所以有bouns reward之後，其reward還是會增長
        next_state, reward, time = self.model[state][action]
        reward += self.time_weight * np.sqrt(self.time - time)
        
        state = deepcopy(state)
        next_state = deepcopy(next_state)
        
        return list(state), action, list(next_state), reward

# %% [markdown]
# 然後我們來設置一下Dyna-Q所需要的參數：
# * gamma: discount factor
# * epsilon: 探索的機率
# * planning_steps: planning steps
# * average_runs: 幾次的run計算平均

# %%
dyna_q_params = {
    'gamma': 0.95,
    'epsilon': 0.1,
    'planning_steps': 10,
    'average_runs': 3,     
    'alpha': 1.0,
    'time_weight': 1e-4,
    'methods': ['Dyna-Q', 'Dyna-Q+']
}

# %%
dyna_q_params
# Out:
# {'gamma': 0.95,
#  'epsilon': 0.1,
#  'planning_steps': 10,
#  'average_runs': 3,
#  'alpha': 1.0,
#  'time_weight': 0.0001,
#  'methods': ['Dyna-Q', 'Dyna-Q+']}

# %% [markdown]
# 設置一個已經很熟悉的，用來選擇action的function

# %%
def action_selection(state, value_function, maze, dyna_params):
    """選擇action的function
    
    後來自己被很多q_value參數搞混，所以就試著分開來命名
    
    state: current state
    value_function: action value function, that is q_value
    maze: object for Maze
    dyna_params: algorithm's parameters
    """
    if np.random.binomial(1, dyna_q_params['epsilon']) == 1:
        return np.random.choice(maze.action_space)
    else:
        # 取得該state的所有可能的action
        values = value_function[state[0], state[1], :]
        return np.random.choice([action for action, value in enumerate(values) if value == np.max(values)])

# %% [markdown]
# 接著來設置Dyna-Q algorithm，下面給出完整演算法的pseudocode

# %% [markdown]
# ![](https://i.imgur.com/jo168Rh.png)

# %%
def dyna_q_algorithm(q_value, model, maze, params,global_steps):
    """dyna_q algorithm
    
    q_value: action-value function
    model: for planning
    maze: environment
    params: for dyna_q's parameters
    
    見上演算法說明
    """
    # (a) current state
    state = maze.START_STATE
    steps = 0
    
    # 一直到agent走到目標之前就是一路迴圈執行
    while state != maze.GOAL_STATE:        
        # 記錄當下的steps
        steps += 1
        
        # (b) 取得action
        

        # if steps % 200 == 0:
        #     print("accumulated")

        action = action_selection(state, q_value, maze, params)
        
        # (c) 執行action，得到next state與reward
        next_state, reward = maze.step(state, action)
        
        # (d) 做一次Q-learning的更新
        q_value[state[0], state[1], action] += \
            params['alpha'] * (reward + params['gamma'] * np.max(q_value[next_state[0], next_state[1], :]) \
                - q_value[state[0], state[1], action])
        
        # (e) 資料寫入模型
        model.feed(state, action, next_state, reward)
        
        # (f) 迴圈執行planning_steps次
        for t in range(0, params['planning_steps']):            
            # 隨機的從模型中取一筆資料
            # 從經驗中學習，其實就是用sample到的資料再做一次更新
            _state, _action, _next_state, _reward = model.sample()
            q_value[_state[0], _state[1], _action] += \
            params['alpha'] * (_reward + params['gamma'] * np.max(q_value[_next_state[0], _next_state[1], :]) \
                - q_value[_state[0], _state[1], _action])
            
        state = next_state
        
        if steps > maze.max_steps:
            break
    
    return steps

# %% [markdown]
# 演算法的部份也已經好了，現在我們可以來處理實際要執行的過程了

# %% [markdown]
# 首先初始化需求的物件

# %%
blocking_maze = Maze()

# %% [markdown]
# 然後我們也已經有env的參數

# %%
dyna_q_params
# Out:
# {'gamma': 0.95,
#  'epsilon': 0.1,
#  'planning_steps': 10,
#  'average_runs': 3,
#  'alpha': 1.0,
#  'time_weight': 0.0001,
#  'methods': ['Dyna-Q', 'Dyna-Q+']}

# %% [markdown]
# 接下來設置一些過程中需要的參數

# %%
max_steps = blocking_maze.max_steps
rewards = np.zeros((dyna_q_params['average_runs'], 2, max_steps))
# 20run、2個model、3000個steps
rewards.shape
# Out:
# (3, 2, 3000)

# %%
# %%time
# 執行20次
for run in tqdm(range(dyna_q_params['average_runs'])):
    # 初始化兩個model
    models = [TrivialModel(), TimeModel(blocking_maze,  dyna_q_params['time_weight'])]
    
    # 初始化兩種演算法的action value
    q_values = [np.zeros(blocking_maze.value_size), np.zeros(blocking_maze.value_size)]
    
    for i in range(len(dyna_q_params['methods'])):
        # 一開始是左邊開個洞的迷宮
        blocking_maze.obstacles = blocking_maze.old_obstacles
        
        # 初始化step
        steps = 0
        last_steps = steps
        # 3000個step為極限做迴圈
        while steps < max_steps:
            steps += dyna_q_algorithm(q_values[i], models[i], blocking_maze, dyna_q_params,steps)
            # 更新reward
            print("Run:", run, " Method:", dyna_q_params['methods'][i], " Steps:", steps)
            # 這個執行區間內的reward都會變成起始那一個reward
            # print("rewards:", rewards[run, i, last_steps: steps])
            rewards[run, i, last_steps: steps] = rewards[run, i, last_steps]
            # 累加reward
            rewards[run, i, min(steps, max_steps - 1)] = rewards[run, i, last_steps] + 1
            
            last_steps = steps
            
            # 1000個step之後環境變換
            if steps > blocking_maze.time_to_switch:
                blocking_maze.obstacles = blocking_maze.new_obstacles
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Run: 0  Method: Dyna-Q  Steps: 536
# Run: 0  Method: Dyna-Q  Steps: 648
# Run: 0  Method: Dyna-Q  Steps: 691
# Run: 0  Method: Dyna-Q  Steps: 719
# Run: 0  Method: Dyna-Q  Steps: 733
# Run: 0  Method: Dyna-Q  Steps: 747
# Run: 0  Method: Dyna-Q  Steps: 764
# Run: 0  Method: Dyna-Q  Steps: 778
# Run: 0  Method: Dyna-Q  Steps: 792
# Run: 0  Method: Dyna-Q  Steps: 806
# Run: 0  Method: Dyna-Q  Steps: 823
# Run: 0  Method: Dyna-Q  Steps: 837
# Run: 0  Method: Dyna-Q  Steps: 852
# Run: 0  Method: Dyna-Q  Steps: 870
# Run: 0  Method: Dyna-Q  Steps: 886
# Run: 0  Method: Dyna-Q  Steps: 902
# Run: 0  Method: Dyna-Q  Steps: 916
# Run: 0  Method: Dyna-Q  Steps: 930
# Run: 0  Method: Dyna-Q  Steps: 946
# Run: 0  Method: Dyna-Q  Steps: 963
# Run: 0  Method: Dyna-Q  Steps: 979
# Run: 0  Method: Dyna-Q  Steps: 995
# Run: 0  Method: Dyna-Q  Steps: 1017
# Run: 0  Method: Dyna-Q  Steps: 1623
# Run: 0  Method: Dyna-Q  Steps: 1688
# Run: 0  Method: Dyna-Q  Steps: 1707
# Run: 0  Method: Dyna-Q  Steps: 1723
# Run: 0  Method: Dyna-Q  Steps: 1742
# Run: 0  Method: Dyna-Q  Steps: 1759
# Run: 0  Method: Dyna-Q  Steps: 1777
# Run: 0  Method: Dyna-Q  Steps: 1799
# Run: 0  Method: Dyna-Q  Steps: 1820
# Run: 0  Method: Dyna-Q  Steps: 1838
# Run: 0  Method: Dyna-Q  Steps: 1858
# Run: 0  Method: Dyna-Q  Steps: 1878
# Run: 0  Method: Dyna-Q  Steps: 1898
# Run: 0  Method: Dyna-Q  Steps: 1917
# Run: 0  Method: Dyna-Q  Steps: 1933
# Run: 0  Method: Dyna-Q  Steps: 1950
# Run: 0  Method: Dyna-Q  Steps: 1970
# Run: 0  Method: Dyna-Q  Steps: 1988
# Run: 0  Method: Dyna-Q  Steps: 2004
# Run: 0  Method: Dyna-Q  Steps: 2022
# Run: 0  Method: Dyna-Q  Steps: 2040
# Run: 0  Method: Dyna-Q  Steps: 2056
# Run: 0  Method: Dyna-Q  Steps: 2072
# Run: 0  Method: Dyna-Q  Steps: 2088
# Run: 0  Method: Dyna-Q  Steps: 2108
# Run: 0  Method: Dyna-Q  Steps: 2125
# Run: 0  Method: Dyna-Q  Steps: 2144
# Run: 0  Method: Dyna-Q  Steps: 2163
# Run: 0  Method: Dyna-Q  Steps: 2179
# Run: 0  Method: Dyna-Q  Steps: 2197
# Run: 0  Method: Dyna-Q  Steps: 2214
# Run: 0  Method: Dyna-Q  Steps: 2232
# Run: 0  Method: Dyna-Q  Steps: 2248
# Run: 0  Method: Dyna-Q  Steps: 2264
# Run: 0  Method: Dyna-Q  Steps: 2280
# Run: 0  Method: Dyna-Q  Steps: 2296
# Run: 0  Method: Dyna-Q  Steps: 2312
# Run: 0  Method: Dyna-Q  Steps: 2331
# Run: 0  Method: Dyna-Q  Steps: 2349
# Run: 0  Method: Dyna-Q  Steps: 2370
# Run: 0  Method: Dyna-Q  Steps: 2393
# Run: 0  Method: Dyna-Q  Steps: 2413
# Run: 0  Method: Dyna-Q  Steps: 2431
# Run: 0  Method: Dyna-Q  Steps: 2449
# Run: 0  Method: Dyna-Q  Steps: 2468
# Run: 0  Method: Dyna-Q  Steps: 2484
# Run: 0  Method: Dyna-Q  Steps: 2501
# Run: 0  Method: Dyna-Q  Steps: 2523
# Run: 0  Method: Dyna-Q  Steps: 2544
# Run: 0  Method: Dyna-Q  Steps: 2560
# Run: 0  Method: Dyna-Q  Steps: 2577
# Run: 0  Method: Dyna-Q  Steps: 2593
# Run: 0  Method: Dyna-Q  Steps: 2611
# Run: 0  Method: Dyna-Q  Steps: 2627
# Run: 0  Method: Dyna-Q  Steps: 2643
# Run: 0  Method: Dyna-Q  Steps: 2661
# Run: 0  Method: Dyna-Q  Steps: 2677
# Run: 0  Method: Dyna-Q  Steps: 2695
# Run: 0  Method: Dyna-Q  Steps: 2715
# Run: 0  Method: Dyna-Q  Steps: 2732
# Run: 0  Method: Dyna-Q  Steps: 2752
# Run: 0  Method: Dyna-Q  Steps: 2776
# Run: 0  Method: Dyna-Q  Steps: 2792
# Run: 0  Method: Dyna-Q  Steps: 2813
# Run: 0  Method: Dyna-Q  Steps: 2831
# Run: 0  Method: Dyna-Q  Steps: 2850
# Run: 0  Method: Dyna-Q  Steps: 2866
# Run: 0  Method: Dyna-Q  Steps: 2883
# Run: 0  Method: Dyna-Q  Steps: 2905
# Run: 0  Method: Dyna-Q  Steps: 2921
# Run: 0  Method: Dyna-Q  Steps: 2939
# Run: 0  Method: Dyna-Q  Steps: 2957
# Run: 0  Method: Dyna-Q  Steps: 2975
# Run: 0  Method: Dyna-Q  Steps: 2994
# Run: 0  Method: Dyna-Q  Steps: 3012
# Run: 0  Method: Dyna-Q+  Steps: 187
# Run: 0  Method: Dyna-Q+  Steps: 225
# Run: 0  Method: Dyna-Q+  Steps: 259
# Run: 0  Method: Dyna-Q+  Steps: 274
# Run: 0  Method: Dyna-Q+  Steps: 285
# Run: 0  Method: Dyna-Q+  Steps: 297
# Run: 0  Method: Dyna-Q+  Steps: 308
# Run: 0  Method: Dyna-Q+  Steps: 320
# Run: 0  Method: Dyna-Q+  Steps: 331
# Run: 0  Method: Dyna-Q+  Steps: 343
# Run: 0  Method: Dyna-Q+  Steps: 353
# Run: 0  Method: Dyna-Q+  Steps: 367
# Run: 0  Method: Dyna-Q+  Steps: 377
# Run: 0  Method: Dyna-Q+  Steps: 387
# Run: 0  Method: Dyna-Q+  Steps: 397
# Run: 0  Method: Dyna-Q+  Steps: 407
# Run: 0  Method: Dyna-Q+  Steps: 417
# Run: 0  Method: Dyna-Q+  Steps: 427
# Run: 0  Method: Dyna-Q+  Steps: 439
# Run: 0  Method: Dyna-Q+  Steps: 451
# Run: 0  Method: Dyna-Q+  Steps: 461
# Run: 0  Method: Dyna-Q+  Steps: 471
# Run: 0  Method: Dyna-Q+  Steps: 481
# Run: 0  Method: Dyna-Q+  Steps: 495
# Run: 0  Method: Dyna-Q+  Steps: 505
# Run: 0  Method: Dyna-Q+  Steps: 516
# Run: 0  Method: Dyna-Q+  Steps: 526
# Run: 0  Method: Dyna-Q+  Steps: 538
# Run: 0  Method: Dyna-Q+  Steps: 552
# Run: 0  Method: Dyna-Q+  Steps: 562
# Run: 0  Method: Dyna-Q+  Steps: 572
# Run: 0  Method: Dyna-Q+  Steps: 582
# Run: 0  Method: Dyna-Q+  Steps: 592
# Run: 0  Method: Dyna-Q+  Steps: 602
# Run: 0  Method: Dyna-Q+  Steps: 616
# Run: 0  Method: Dyna-Q+  Steps: 629
# Run: 0  Method: Dyna-Q+  Steps: 640
# Run: 0  Method: Dyna-Q+  Steps: 654
# Run: 0  Method: Dyna-Q+  Steps: 665
# Run: 0  Method: Dyna-Q+  Steps: 676
# Run: 0  Method: Dyna-Q+  Steps: 686
# Run: 0  Method: Dyna-Q+  Steps: 698
# Run: 0  Method: Dyna-Q+  Steps: 710
# Run: 0  Method: Dyna-Q+  Steps: 720
# Run: 0  Method: Dyna-Q+  Steps: 730
# Run: 0  Method: Dyna-Q+  Steps: 740
# Run: 0  Method: Dyna-Q+  Steps: 751
# Run: 0  Method: Dyna-Q+  Steps: 763
# Run: 0  Method: Dyna-Q+  Steps: 773
# Run: 0  Method: Dyna-Q+  Steps: 783
# Run: 0  Method: Dyna-Q+  Steps: 793
# Run: 0  Method: Dyna-Q+  Steps: 803
# Run: 0  Method: Dyna-Q+  Steps: 814
# Run: 0  Method: Dyna-Q+  Steps: 826
# Run: 0  Method: Dyna-Q+  Steps: 836
# Run: 0  Method: Dyna-Q+  Steps: 849
# Run: 0  Method: Dyna-Q+  Steps: 859
# Run: 0  Method: Dyna-Q+  Steps: 871
# Run: 0  Method: Dyna-Q+  Steps: 881
# Run: 0  Method: Dyna-Q+  Steps: 891
# Run: 0  Method: Dyna-Q+  Steps: 901
# Run: 0  Method: Dyna-Q+  Steps: 914
# Run: 0  Method: Dyna-Q+  Steps: 924
# Run: 0  Method: Dyna-Q+  Steps: 936
# Run: 0  Method: Dyna-Q+  Steps: 946
# Run: 0  Method: Dyna-Q+  Steps: 956
# Run: 0  Method: Dyna-Q+  Steps: 966
# Run: 0  Method: Dyna-Q+  Steps: 978
# Run: 0  Method: Dyna-Q+  Steps: 990
# Run: 0  Method: Dyna-Q+  Steps: 1000
# Run: 0  Method: Dyna-Q+  Steps: 1010
# Run: 0  Method: Dyna-Q+  Steps: 1411
# Run: 0  Method: Dyna-Q+  Steps: 1581
# Run: 0  Method: Dyna-Q+  Steps: 1604
# Run: 0  Method: Dyna-Q+  Steps: 1622
# Run: 0  Method: Dyna-Q+  Steps: 1638
# Run: 0  Method: Dyna-Q+  Steps: 1656
# Run: 0  Method: Dyna-Q+  Steps: 1674
# Run: 0  Method: Dyna-Q+  Steps: 1690
# Run: 0  Method: Dyna-Q+  Steps: 1707
# Run: 0  Method: Dyna-Q+  Steps: 1728
# Run: 0  Method: Dyna-Q+  Steps: 1744
# Run: 0  Method: Dyna-Q+  Steps: 1760
# Run: 0  Method: Dyna-Q+  Steps: 1778
# Run: 0  Method: Dyna-Q+  Steps: 1796
# Run: 0  Method: Dyna-Q+  Steps: 1813
# Run: 0  Method: Dyna-Q+  Steps: 1834
# Run: 0  Method: Dyna-Q+  Steps: 1852
# Run: 0  Method: Dyna-Q+  Steps: 1868
# Run: 0  Method: Dyna-Q+  Steps: 1884
# Run: 0  Method: Dyna-Q+  Steps: 1901
# Run: 0  Method: Dyna-Q+  Steps: 1919
# Run: 0  Method: Dyna-Q+  Steps: 1936
# Run: 0  Method: Dyna-Q+  Steps: 1952
# Run: 0  Method: Dyna-Q+  Steps: 1973
# Run: 0  Method: Dyna-Q+  Steps: 1992
# Run: 0  Method: Dyna-Q+  Steps: 2012
# Run: 0  Method: Dyna-Q+  Steps: 2028
# Run: 0  Method: Dyna-Q+  Steps: 2047
# Run: 0  Method: Dyna-Q+  Steps: 2065
# Run: 0  Method: Dyna-Q+  Steps: 2087
# Run: 0  Method: Dyna-Q+  Steps: 2104
# Run: 0  Method: Dyna-Q+  Steps: 2120
# Run: 0  Method: Dyna-Q+  Steps: 2143
# Run: 0  Method: Dyna-Q+  Steps: 2160
# Run: 0  Method: Dyna-Q+  Steps: 2179
# Run: 0  Method: Dyna-Q+  Steps: 2197
# Run: 0  Method: Dyna-Q+  Steps: 2216
# Run: 0  Method: Dyna-Q+  Steps: 2232
# Run: 0  Method: Dyna-Q+  Steps: 2251
# Run: 0  Method: Dyna-Q+  Steps: 2270
# Run: 0  Method: Dyna-Q+  Steps: 2287
# Run: 0  Method: Dyna-Q+  Steps: 2307
# Run: 0  Method: Dyna-Q+  Steps: 2326
# Run: 0  Method: Dyna-Q+  Steps: 2342
# Run: 0  Method: Dyna-Q+  Steps: 2358
# Run: 0  Method: Dyna-Q+  Steps: 2376
# Run: 0  Method: Dyna-Q+  Steps: 2394
# Run: 0  Method: Dyna-Q+  Steps: 2413
# Run: 0  Method: Dyna-Q+  Steps: 2431
# Run: 0  Method: Dyna-Q+  Steps: 2449
# Run: 0  Method: Dyna-Q+  Steps: 2469
# Run: 0  Method: Dyna-Q+  Steps: 2487
# Run: 0  Method: Dyna-Q+  Steps: 2505
# Run: 0  Method: Dyna-Q+  Steps: 2526
# Run: 0  Method: Dyna-Q+  Steps: 2542
# Run: 0  Method: Dyna-Q+  Steps: 2559
# Run: 0  Method: Dyna-Q+  Steps: 2577
# Run: 0  Method: Dyna-Q+  Steps: 2594
# Run: 0  Method: Dyna-Q+  Steps: 2611
# Run: 0  Method: Dyna-Q+  Steps: 2629
# Run: 0  Method: Dyna-Q+  Steps: 2650
# Run: 0  Method: Dyna-Q+  Steps: 2666
# Run: 0  Method: Dyna-Q+  Steps: 2687
# Run: 0  Method: Dyna-Q+  Steps: 2705
# Run: 0  Method: Dyna-Q+  Steps: 2727
# Run: 0  Method: Dyna-Q+  Steps: 2743
# Run: 0  Method: Dyna-Q+  Steps: 2762
#  33%|███▎      | 1/3 [00:04<00:08,  4.10s/it]
# Run: 0  Method: Dyna-Q+  Steps: 2785
# Run: 0  Method: Dyna-Q+  Steps: 2806
# Run: 0  Method: Dyna-Q+  Steps: 2826
# Run: 0  Method: Dyna-Q+  Steps: 2843
# Run: 0  Method: Dyna-Q+  Steps: 2865
# Run: 0  Method: Dyna-Q+  Steps: 2883
# Run: 0  Method: Dyna-Q+  Steps: 2903
# Run: 0  Method: Dyna-Q+  Steps: 2924
# Run: 0  Method: Dyna-Q+  Steps: 2942
# Run: 0  Method: Dyna-Q+  Steps: 2960
# Run: 0  Method: Dyna-Q+  Steps: 2977
# Run: 0  Method: Dyna-Q+  Steps: 2993
# Run: 0  Method: Dyna-Q+  Steps: 3010
# Run: 1  Method: Dyna-Q  Steps: 898
# Run: 1  Method: Dyna-Q  Steps: 1044
# Run: 1  Method: Dyna-Q  Steps: 4045
# Run: 1  Method: Dyna-Q+  Steps: 185
# Run: 1  Method: Dyna-Q+  Steps: 227
# Run: 1  Method: Dyna-Q+  Steps: 241
# Run: 1  Method: Dyna-Q+  Steps: 251
# Run: 1  Method: Dyna-Q+  Steps: 262
# Run: 1  Method: Dyna-Q+  Steps: 272
# Run: 1  Method: Dyna-Q+  Steps: 282
# Run: 1  Method: Dyna-Q+  Steps: 292
# Run: 1  Method: Dyna-Q+  Steps: 302
# Run: 1  Method: Dyna-Q+  Steps: 312
# Run: 1  Method: Dyna-Q+  Steps: 322
# Run: 1  Method: Dyna-Q+  Steps: 333
# Run: 1  Method: Dyna-Q+  Steps: 344
# Run: 1  Method: Dyna-Q+  Steps: 355
# Run: 1  Method: Dyna-Q+  Steps: 365
# Run: 1  Method: Dyna-Q+  Steps: 379
# Run: 1  Method: Dyna-Q+  Steps: 391
# Run: 1  Method: Dyna-Q+  Steps: 401
# Run: 1  Method: Dyna-Q+  Steps: 413
# Run: 1  Method: Dyna-Q+  Steps: 424
# Run: 1  Method: Dyna-Q+  Steps: 539
# Run: 1  Method: Dyna-Q+  Steps: 549
# Run: 1  Method: Dyna-Q+  Steps: 559
# Run: 1  Method: Dyna-Q+  Steps: 569
# Run: 1  Method: Dyna-Q+  Steps: 579
# Run: 1  Method: Dyna-Q+  Steps: 591
# Run: 1  Method: Dyna-Q+  Steps: 601
# Run: 1  Method: Dyna-Q+  Steps: 611
# Run: 1  Method: Dyna-Q+  Steps: 621
# Run: 1  Method: Dyna-Q+  Steps: 631
# Run: 1  Method: Dyna-Q+  Steps: 642
# Run: 1  Method: Dyna-Q+  Steps: 654
# Run: 1  Method: Dyna-Q+  Steps: 666
# Run: 1  Method: Dyna-Q+  Steps: 678
# Run: 1  Method: Dyna-Q+  Steps: 690
# Run: 1  Method: Dyna-Q+  Steps: 700
# Run: 1  Method: Dyna-Q+  Steps: 710
# Run: 1  Method: Dyna-Q+  Steps: 720
# Run: 1  Method: Dyna-Q+  Steps: 735
# Run: 1  Method: Dyna-Q+  Steps: 746
# Run: 1  Method: Dyna-Q+  Steps: 756
# Run: 1  Method: Dyna-Q+  Steps: 770
# Run: 1  Method: Dyna-Q+  Steps: 780
# Run: 1  Method: Dyna-Q+  Steps: 791
# Run: 1  Method: Dyna-Q+  Steps: 801
# Run: 1  Method: Dyna-Q+  Steps: 811
# Run: 1  Method: Dyna-Q+  Steps: 821
# Run: 1  Method: Dyna-Q+  Steps: 831
# Run: 1  Method: Dyna-Q+  Steps: 841
# Run: 1  Method: Dyna-Q+  Steps: 851
# Run: 1  Method: Dyna-Q+  Steps: 865
# Run: 1  Method: Dyna-Q+  Steps: 875
# Run: 1  Method: Dyna-Q+  Steps: 885
# Run: 1  Method: Dyna-Q+  Steps: 896
# Run: 1  Method: Dyna-Q+  Steps: 906
# Run: 1  Method: Dyna-Q+  Steps: 916
# Run: 1  Method: Dyna-Q+  Steps: 928
# Run: 1  Method: Dyna-Q+  Steps: 939
# Run: 1  Method: Dyna-Q+  Steps: 949
# Run: 1  Method: Dyna-Q+  Steps: 960
# Run: 1  Method: Dyna-Q+  Steps: 970
# Run: 1  Method: Dyna-Q+  Steps: 983
# Run: 1  Method: Dyna-Q+  Steps: 994
# Run: 1  Method: Dyna-Q+  Steps: 1006
# Run: 1  Method: Dyna-Q+  Steps: 1439
# Run: 1  Method: Dyna-Q+  Steps: 1460
# Run: 1  Method: Dyna-Q+  Steps: 1482
# Run: 1  Method: Dyna-Q+  Steps: 1498
# Run: 1  Method: Dyna-Q+  Steps: 1515
# Run: 1  Method: Dyna-Q+  Steps: 1535
# Run: 1  Method: Dyna-Q+  Steps: 1552
# Run: 1  Method: Dyna-Q+  Steps: 1568
# Run: 1  Method: Dyna-Q+  Steps: 1584
# Run: 1  Method: Dyna-Q+  Steps: 1608
# Run: 1  Method: Dyna-Q+  Steps: 1624
# Run: 1  Method: Dyna-Q+  Steps: 1644
# Run: 1  Method: Dyna-Q+  Steps: 1662
# Run: 1  Method: Dyna-Q+  Steps: 1678
# Run: 1  Method: Dyna-Q+  Steps: 1701
# Run: 1  Method: Dyna-Q+  Steps: 1719
# Run: 1  Method: Dyna-Q+  Steps: 1744
# Run: 1  Method: Dyna-Q+  Steps: 1764
# Run: 1  Method: Dyna-Q+  Steps: 1784
# Run: 1  Method: Dyna-Q+  Steps: 1802
# Run: 1  Method: Dyna-Q+  Steps: 1821
# Run: 1  Method: Dyna-Q+  Steps: 1840
# Run: 1  Method: Dyna-Q+  Steps: 1859
# Run: 1  Method: Dyna-Q+  Steps: 1879
# Run: 1  Method: Dyna-Q+  Steps: 1897
# Run: 1  Method: Dyna-Q+  Steps: 1915
# Run: 1  Method: Dyna-Q+  Steps: 1935
# Run: 1  Method: Dyna-Q+  Steps: 1951
# Run: 1  Method: Dyna-Q+  Steps: 1969
# Run: 1  Method: Dyna-Q+  Steps: 1990
# Run: 1  Method: Dyna-Q+  Steps: 2006
# Run: 1  Method: Dyna-Q+  Steps: 2025
# Run: 1  Method: Dyna-Q+  Steps: 2045
# Run: 1  Method: Dyna-Q+  Steps: 2067
# Run: 1  Method: Dyna-Q+  Steps: 2086
# Run: 1  Method: Dyna-Q+  Steps: 2102
# Run: 1  Method: Dyna-Q+  Steps: 2120
# Run: 1  Method: Dyna-Q+  Steps: 2136
# Run: 1  Method: Dyna-Q+  Steps: 2152
# Run: 1  Method: Dyna-Q+  Steps: 2171
# Run: 1  Method: Dyna-Q+  Steps: 2189
# Run: 1  Method: Dyna-Q+  Steps: 2205
# Run: 1  Method: Dyna-Q+  Steps: 2221
# Run: 1  Method: Dyna-Q+  Steps: 2238
# Run: 1  Method: Dyna-Q+  Steps: 2255
# Run: 1  Method: Dyna-Q+  Steps: 2273
# Run: 1  Method: Dyna-Q+  Steps: 2289
# Run: 1  Method: Dyna-Q+  Steps: 2306
# Run: 1  Method: Dyna-Q+  Steps: 2322
# Run: 1  Method: Dyna-Q+  Steps: 2339
# Run: 1  Method: Dyna-Q+  Steps: 2356
# Run: 1  Method: Dyna-Q+  Steps: 2373
# Run: 1  Method: Dyna-Q+  Steps: 2391
# Run: 1  Method: Dyna-Q+  Steps: 2409
# Run: 1  Method: Dyna-Q+  Steps: 2427
# Run: 1  Method: Dyna-Q+  Steps: 2445
# Run: 1  Method: Dyna-Q+  Steps: 2463
# Run: 1  Method: Dyna-Q+  Steps: 2480
# Run: 1  Method: Dyna-Q+  Steps: 2497
# Run: 1  Method: Dyna-Q+  Steps: 2515
# Run: 1  Method: Dyna-Q+  Steps: 2534
# Run: 1  Method: Dyna-Q+  Steps: 2550
# Run: 1  Method: Dyna-Q+  Steps: 2569
# Run: 1  Method: Dyna-Q+  Steps: 2593
# Run: 1  Method: Dyna-Q+  Steps: 2611
# Run: 1  Method: Dyna-Q+  Steps: 2629
# Run: 1  Method: Dyna-Q+  Steps: 2649
# Run: 1  Method: Dyna-Q+  Steps: 2665
# Run: 1  Method: Dyna-Q+  Steps: 2682
# Run: 1  Method: Dyna-Q+  Steps: 2698
# Run: 1  Method: Dyna-Q+  Steps: 2714
# Run: 1  Method: Dyna-Q+  Steps: 2730
# Run: 1  Method: Dyna-Q+  Steps: 2749
# Run: 1  Method: Dyna-Q+  Steps: 2765
# Run: 1  Method: Dyna-Q+  Steps: 2781
# Run: 1  Method: Dyna-Q+  Steps: 2797
# Run: 1  Method: Dyna-Q+  Steps: 2813
# Run: 1  Method: Dyna-Q+  Steps: 2829
# Run: 1  Method: Dyna-Q+  Steps: 2845
# Run: 1  Method: Dyna-Q+  Steps: 2864
# Run: 1  Method: Dyna-Q+  Steps: 2880
#  67%|██████▋   | 2/3 [00:08<00:04,  4.42s/it]
# Run: 1  Method: Dyna-Q+  Steps: 2905
# Run: 1  Method: Dyna-Q+  Steps: 2922
# Run: 1  Method: Dyna-Q+  Steps: 2938
# Run: 1  Method: Dyna-Q+  Steps: 2956
# Run: 1  Method: Dyna-Q+  Steps: 2976
# Run: 1  Method: Dyna-Q+  Steps: 2992
# Run: 1  Method: Dyna-Q+  Steps: 3008
# Run: 2  Method: Dyna-Q  Steps: 180
# Run: 2  Method: Dyna-Q  Steps: 242
# Run: 2  Method: Dyna-Q  Steps: 254
# Run: 2  Method: Dyna-Q  Steps: 268
# Run: 2  Method: Dyna-Q  Steps: 284
# Run: 2  Method: Dyna-Q  Steps: 296
# Run: 2  Method: Dyna-Q  Steps: 309
# Run: 2  Method: Dyna-Q  Steps: 321
# Run: 2  Method: Dyna-Q  Steps: 333
# Run: 2  Method: Dyna-Q  Steps: 345
# Run: 2  Method: Dyna-Q  Steps: 358
# Run: 2  Method: Dyna-Q  Steps: 371
# Run: 2  Method: Dyna-Q  Steps: 385
# Run: 2  Method: Dyna-Q  Steps: 399
# Run: 2  Method: Dyna-Q  Steps: 411
# Run: 2  Method: Dyna-Q  Steps: 423
# Run: 2  Method: Dyna-Q  Steps: 440
# Run: 2  Method: Dyna-Q  Steps: 454
# Run: 2  Method: Dyna-Q  Steps: 468
# Run: 2  Method: Dyna-Q  Steps: 480
# Run: 2  Method: Dyna-Q  Steps: 497
# Run: 2  Method: Dyna-Q  Steps: 509
# Run: 2  Method: Dyna-Q  Steps: 522
# Run: 2  Method: Dyna-Q  Steps: 536
# Run: 2  Method: Dyna-Q  Steps: 548
# Run: 2  Method: Dyna-Q  Steps: 561
# Run: 2  Method: Dyna-Q  Steps: 574
# Run: 2  Method: Dyna-Q  Steps: 586
# Run: 2  Method: Dyna-Q  Steps: 598
# Run: 2  Method: Dyna-Q  Steps: 613
# Run: 2  Method: Dyna-Q  Steps: 627
# Run: 2  Method: Dyna-Q  Steps: 641
# Run: 2  Method: Dyna-Q  Steps: 654
# Run: 2  Method: Dyna-Q  Steps: 666
# Run: 2  Method: Dyna-Q  Steps: 678
# Run: 2  Method: Dyna-Q  Steps: 692
# Run: 2  Method: Dyna-Q  Steps: 709
# Run: 2  Method: Dyna-Q  Steps: 722
# Run: 2  Method: Dyna-Q  Steps: 737
# Run: 2  Method: Dyna-Q  Steps: 755
# Run: 2  Method: Dyna-Q  Steps: 769
# Run: 2  Method: Dyna-Q  Steps: 783
# Run: 2  Method: Dyna-Q  Steps: 798
# Run: 2  Method: Dyna-Q  Steps: 810
# Run: 2  Method: Dyna-Q  Steps: 822
# Run: 2  Method: Dyna-Q  Steps: 838
# Run: 2  Method: Dyna-Q  Steps: 850
# Run: 2  Method: Dyna-Q  Steps: 864
# Run: 2  Method: Dyna-Q  Steps: 878
# Run: 2  Method: Dyna-Q  Steps: 891
# Run: 2  Method: Dyna-Q  Steps: 903
# Run: 2  Method: Dyna-Q  Steps: 915
# Run: 2  Method: Dyna-Q  Steps: 927
# Run: 2  Method: Dyna-Q  Steps: 941
# Run: 2  Method: Dyna-Q  Steps: 953
# Run: 2  Method: Dyna-Q  Steps: 966
# Run: 2  Method: Dyna-Q  Steps: 981
# Run: 2  Method: Dyna-Q  Steps: 995
# Run: 2  Method: Dyna-Q  Steps: 1007
# Run: 2  Method: Dyna-Q  Steps: 4008
# Run: 2  Method: Dyna-Q+  Steps: 290
# Run: 2  Method: Dyna-Q+  Steps: 313
# Run: 2  Method: Dyna-Q+  Steps: 341
# Run: 2  Method: Dyna-Q+  Steps: 363
# Run: 2  Method: Dyna-Q+  Steps: 384
# Run: 2  Method: Dyna-Q+  Steps: 395
# Run: 2  Method: Dyna-Q+  Steps: 409
# Run: 2  Method: Dyna-Q+  Steps: 420
# Run: 2  Method: Dyna-Q+  Steps: 430
# Run: 2  Method: Dyna-Q+  Steps: 440
# Run: 2  Method: Dyna-Q+  Steps: 450
# Run: 2  Method: Dyna-Q+  Steps: 460
# Run: 2  Method: Dyna-Q+  Steps: 470
# Run: 2  Method: Dyna-Q+  Steps: 482
# Run: 2  Method: Dyna-Q+  Steps: 494
# Run: 2  Method: Dyna-Q+  Steps: 504
# Run: 2  Method: Dyna-Q+  Steps: 514
# Run: 2  Method: Dyna-Q+  Steps: 524
# Run: 2  Method: Dyna-Q+  Steps: 535
# Run: 2  Method: Dyna-Q+  Steps: 549
# Run: 2  Method: Dyna-Q+  Steps: 559
# Run: 2  Method: Dyna-Q+  Steps: 569
# Run: 2  Method: Dyna-Q+  Steps: 579
# Run: 2  Method: Dyna-Q+  Steps: 589
# Run: 2  Method: Dyna-Q+  Steps: 601
# Run: 2  Method: Dyna-Q+  Steps: 613
# Run: 2  Method: Dyna-Q+  Steps: 625
# Run: 2  Method: Dyna-Q+  Steps: 635
# Run: 2  Method: Dyna-Q+  Steps: 652
# Run: 2  Method: Dyna-Q+  Steps: 662
# Run: 2  Method: Dyna-Q+  Steps: 672
# Run: 2  Method: Dyna-Q+  Steps: 682
# Run: 2  Method: Dyna-Q+  Steps: 692
# Run: 2  Method: Dyna-Q+  Steps: 702
# Run: 2  Method: Dyna-Q+  Steps: 713
# Run: 2  Method: Dyna-Q+  Steps: 725
# Run: 2  Method: Dyna-Q+  Steps: 735
# Run: 2  Method: Dyna-Q+  Steps: 747
# Run: 2  Method: Dyna-Q+  Steps: 759
# Run: 2  Method: Dyna-Q+  Steps: 769
# Run: 2  Method: Dyna-Q+  Steps: 781
# Run: 2  Method: Dyna-Q+  Steps: 791
# Run: 2  Method: Dyna-Q+  Steps: 803
# Run: 2  Method: Dyna-Q+  Steps: 813
# Run: 2  Method: Dyna-Q+  Steps: 823
# Run: 2  Method: Dyna-Q+  Steps: 833
# Run: 2  Method: Dyna-Q+  Steps: 843
# Run: 2  Method: Dyna-Q+  Steps: 854
# Run: 2  Method: Dyna-Q+  Steps: 864
# Run: 2  Method: Dyna-Q+  Steps: 874
# Run: 2  Method: Dyna-Q+  Steps: 884
# Run: 2  Method: Dyna-Q+  Steps: 894
# Run: 2  Method: Dyna-Q+  Steps: 904
# Run: 2  Method: Dyna-Q+  Steps: 914
# Run: 2  Method: Dyna-Q+  Steps: 926
# Run: 2  Method: Dyna-Q+  Steps: 937
# Run: 2  Method: Dyna-Q+  Steps: 947
# Run: 2  Method: Dyna-Q+  Steps: 961
# Run: 2  Method: Dyna-Q+  Steps: 975
# Run: 2  Method: Dyna-Q+  Steps: 985
# Run: 2  Method: Dyna-Q+  Steps: 995
# Run: 2  Method: Dyna-Q+  Steps: 1005
# Run: 2  Method: Dyna-Q+  Steps: 2003
# Run: 2  Method: Dyna-Q+  Steps: 2046
# Run: 2  Method: Dyna-Q+  Steps: 2069
# Run: 2  Method: Dyna-Q+  Steps: 2122
# Run: 2  Method: Dyna-Q+  Steps: 2140
# Run: 2  Method: Dyna-Q+  Steps: 2165
# Run: 2  Method: Dyna-Q+  Steps: 2183
# Run: 2  Method: Dyna-Q+  Steps: 2205
# Run: 2  Method: Dyna-Q+  Steps: 2221
# Run: 2  Method: Dyna-Q+  Steps: 2243
# Run: 2  Method: Dyna-Q+  Steps: 2260
# Run: 2  Method: Dyna-Q+  Steps: 2276
# Run: 2  Method: Dyna-Q+  Steps: 2295
# Run: 2  Method: Dyna-Q+  Steps: 2311
# Run: 2  Method: Dyna-Q+  Steps: 2329
# Run: 2  Method: Dyna-Q+  Steps: 2345
# Run: 2  Method: Dyna-Q+  Steps: 2361
# Run: 2  Method: Dyna-Q+  Steps: 2381
# Run: 2  Method: Dyna-Q+  Steps: 2399
# Run: 2  Method: Dyna-Q+  Steps: 2415
# Run: 2  Method: Dyna-Q+  Steps: 2432
# Run: 2  Method: Dyna-Q+  Steps: 2452
# Run: 2  Method: Dyna-Q+  Steps: 2468
# Run: 2  Method: Dyna-Q+  Steps: 2484
# Run: 2  Method: Dyna-Q+  Steps: 2508
# Run: 2  Method: Dyna-Q+  Steps: 2524
# Run: 2  Method: Dyna-Q+  Steps: 2543
# Run: 2  Method: Dyna-Q+  Steps: 2559
# Run: 2  Method: Dyna-Q+  Steps: 2576
# Run: 2  Method: Dyna-Q+  Steps: 2592
# Run: 2  Method: Dyna-Q+  Steps: 2609
# Run: 2  Method: Dyna-Q+  Steps: 2628
# Run: 2  Method: Dyna-Q+  Steps: 2644
# Run: 2  Method: Dyna-Q+  Steps: 2665
# Run: 2  Method: Dyna-Q+  Steps: 2684
# Run: 2  Method: Dyna-Q+  Steps: 2704
# Run: 2  Method: Dyna-Q+  Steps: 2720
# Run: 2  Method: Dyna-Q+  Steps: 2738
# Run: 2  Method: Dyna-Q+  Steps: 2754
# Run: 2  Method: Dyna-Q+  Steps: 2770
# Run: 2  Method: Dyna-Q+  Steps: 2786
# 100%|██████████| 3/3 [00:13<00:00,  4.44s/it]
# Run: 2  Method: Dyna-Q+  Steps: 2802
# Run: 2  Method: Dyna-Q+  Steps: 2825
# Run: 2  Method: Dyna-Q+  Steps: 2843
# Run: 2  Method: Dyna-Q+  Steps: 2859
# Run: 2  Method: Dyna-Q+  Steps: 2876
# Run: 2  Method: Dyna-Q+  Steps: 2892
# Run: 2  Method: Dyna-Q+  Steps: 2910
# Run: 2  Method: Dyna-Q+  Steps: 2933
# Run: 2  Method: Dyna-Q+  Steps: 2952
# Run: 2  Method: Dyna-Q+  Steps: 2972
# Run: 2  Method: Dyna-Q+  Steps: 2990
# Run: 2  Method: Dyna-Q+  Steps: 3009
# CPU times: total: 13.6 s
# Wall time: 13.3 s

# %% [markdown]
# 計算平均

# %%
# 延著0軸計算平均，所以0軸消失
rewards = rewards.mean(axis=0)
print(rewards)
rewards.shape
# Out:
# [[  0.           0.           0.         ...  52.66666667  52.66666667
#    53.66666667]
#  [  0.           0.           0.         ... 138.33333333 138.33333333
#   139.33333333]]
# (2, 3000)

# %% [markdown]
# 繪製圖面

# %%
plt.figure(figsize=(16, 10))

for i in range(len(dyna_q_params['methods'])):
    plt.plot(rewards[i, :], label=dyna_q_params['methods'][i])

plt.xlabel('time steps')
plt.ylabel('cumulative reward')
plt.legend()
plt.show()

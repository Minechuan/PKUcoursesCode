# %%
# !pip install peft==0.14.0
# !pip install -U datasets==3.3.2
# Out:
# Requirement already satisfied: peft==0.14.0 in f:\project\python3.10.11\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.17 in f:\project\python3.10.11\lib\site-packages (from peft==0.14.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in f:\project\python3.10.11\lib\site-packages (from peft==0.14.0) (24.1)
# Requirement already satisfied: psutil in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from peft==0.14.0) (6.1.0)
# Requirement already satisfied: pyyaml in f:\project\python3.10.11\lib\site-packages (from peft==0.14.0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in f:\project\python3.10.11\lib\site-packages (from peft==0.14.0) (2.5.1+cu121)
# Requirement already satisfied: transformers in f:\project\python3.10.11\lib\site-packages (from peft==0.14.0) (4.51.3)
# Requirement already satisfied: tqdm in f:\project\python3.10.11\lib\site-packages (from peft==0.14.0) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in f:\project\python3.10.11\lib\site-packages (from peft==0.14.0) (1.4.0)
# Requirement already satisfied: safetensors in f:\project\python3.10.11\lib\site-packages (from peft==0.14.0) (0.4.3)
# Requirement already satisfied: huggingface-hub>=0.25.0 in f:\project\python3.10.11\lib\site-packages (from peft==0.14.0) (0.30.2)
# Requirement already satisfied: filelock in f:\project\python3.10.11\lib\site-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (3.15.3)
# Requirement already satisfied: fsspec>=2023.5.0 in f:\project\python3.10.11\lib\site-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (2024.6.0)
# Requirement already satisfied: requests in f:\project\python3.10.11\lib\site-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in f:\project\python3.10.11\lib\site-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (4.12.2)
# Requirement already satisfied: networkx in f:\project\python3.10.11\lib\site-packages (from torch>=1.13.0->peft==0.14.0) (3.3)
# Requirement already satisfied: jinja2 in f:\project\python3.10.11\lib\site-packages (from torch>=1.13.0->peft==0.14.0) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in f:\project\python3.10.11\lib\site-packages (from torch>=1.13.0->peft==0.14.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in f:\project\python3.10.11\lib\site-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.14.0) (1.3.0)
# Requirement already satisfied: colorama in f:\project\python3.10.11\lib\site-packages (from tqdm->peft==0.14.0) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in f:\project\python3.10.11\lib\site-packages (from transformers->peft==0.14.0) (2024.5.15)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in f:\project\python3.10.11\lib\site-packages (from transformers->peft==0.14.0) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\project\python3.10.11\lib\site-packages (from jinja2->torch>=1.13.0->peft==0.14.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\project\python3.10.11\lib\site-packages (from requests->huggingface-hub>=0.25.0->peft==0.14.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\project\python3.10.11\lib\site-packages (from requests->huggingface-hub>=0.25.0->peft==0.14.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\project\python3.10.11\lib\site-packages (from requests->huggingface-hub>=0.25.0->peft==0.14.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in f:\project\python3.10.11\lib\site-packages (from requests->huggingface-hub>=0.25.0->peft==0.14.0) (2024.7.4)
# Requirement already satisfied: datasets==3.3.2 in f:\project\python3.10.11\lib\site-packages (3.3.2)
# Requirement already satisfied: filelock in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (3.15.3)
# Requirement already satisfied: numpy>=1.17 in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (0.3.8)
# Requirement already satisfied: pandas in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (4.66.4)
# Requirement already satisfied: xxhash in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in f:\project\python3.10.11\lib\site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets==3.3.2) (2024.6.0)
# Requirement already satisfied: aiohttp in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.24.0 in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (0.30.2)
# Requirement already satisfied: packaging in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in f:\project\python3.10.11\lib\site-packages (from datasets==3.3.2) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in f:\project\python3.10.11\lib\site-packages (from aiohttp->datasets==3.3.2) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in f:\project\python3.10.11\lib\site-packages (from aiohttp->datasets==3.3.2) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in f:\project\python3.10.11\lib\site-packages (from aiohttp->datasets==3.3.2) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in f:\project\python3.10.11\lib\site-packages (from aiohttp->datasets==3.3.2) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in f:\project\python3.10.11\lib\site-packages (from aiohttp->datasets==3.3.2) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in f:\project\python3.10.11\lib\site-packages (from aiohttp->datasets==3.3.2) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in f:\project\python3.10.11\lib\site-packages (from huggingface-hub>=0.24.0->datasets==3.3.2) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\project\python3.10.11\lib\site-packages (from requests>=2.32.2->datasets==3.3.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\project\python3.10.11\lib\site-packages (from requests>=2.32.2->datasets==3.3.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\project\python3.10.11\lib\site-packages (from requests>=2.32.2->datasets==3.3.2) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in f:\project\python3.10.11\lib\site-packages (from requests>=2.32.2->datasets==3.3.2) (2024.7.4)
# Requirement already satisfied: colorama in f:\project\python3.10.11\lib\site-packages (from tqdm>=4.66.3->datasets==3.3.2) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\project\python3.10.11\lib\site-packages (from pandas->datasets==3.3.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\project\python3.10.11\lib\site-packages (from pandas->datasets==3.3.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in f:\project\python3.10.11\lib\site-packages (from pandas->datasets==3.3.2) (2024.1)
# Requirement already satisfied: six>=1.5 in f:\project\python3.10.11\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets==3.3.2) (1.16.0)

# %% [markdown]
# 加载模型和tokenizer

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "bigscience/bloomz-560m"
#model_name="bigscience/bloom-1b1"

tokenizer = AutoTokenizer.from_pretrained(model_name)
foundation_model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from transformers import AutoModelForCausalLM, AutoTokenizer
#       3 model_name = "bigscience/bloomz-560m"
#       4 #model_name="bigscience/bloom-1b1"
#
# File f:\project\python3.10.11\lib\site-packages\transformers\__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File f:\project\python3.10.11\lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File f:\project\python3.10.11\lib\site-packages\transformers\utils\__init__.py:25
#      23 from .. import __version__
#      24 from .backbone_utils import BackboneConfigMixin, BackboneMixin
# ---> 25 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#      26 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      27 from .doc import (
#      28     add_code_sample_docstrings,
#      29     add_end_docstrings,
#    (...)
#      33     replace_return_docstrings,
#      34 )
#
# File f:\project\python3.10.11\lib\site-packages\transformers\utils\chat_template_utils.py:40
#      37     from PIL.Image import Image
#      39 if is_torch_available():
# ---> 40     from torch import Tensor
#      43 BASIC_TYPES = (int, float, str, bool, Any, type(None), ...)
#      44 # Extracts the initial segment of the docstring, containing the function description
#
# File f:\project\python3.10.11\lib\site-packages\torch\__init__.py:2486
#    2482 from torch.func import vmap as vmap
#    2485 if not TYPE_CHECKING:
# -> 2486     from torch import _meta_registrations
#    2488 # Enable CUDA Sanitizer
#    2489 if "TORCH_CUDA_SANITIZER" in os.environ:
#
# File f:\project\python3.10.11\lib\site-packages\torch\_meta_registrations.py:10
#       8 import torch._prims_common as utils
#       9 from torch import SymBool, SymFloat, Tensor
# ---> 10 from torch._decomp import (
#      11     _add_op_to_registry,
#      12     _convert_out_params,
#      13     global_decomposition_table,
#      14     meta_table,
#      15 )
#      16 from torch._ops import OpOverload
#      17 from torch._prims import _prim_elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# File f:\project\python3.10.11\lib\site-packages\torch\_decomp\__init__.py:249
#     245             decompositions.pop(op, None)
#     248 # populate the table
# --> 249 import torch._decomp.decompositions
#     250 import torch._refs
#     253 # See NOTE [Core ATen Ops]
#     254 #
#     255 # list was copied from torch/_inductor/decomposition.py
#     256 # excluding decompositions that results in prim ops
#     257 # Resulting opset of decomposition is core aten ops
#
# File f:\project\python3.10.11\lib\site-packages\torch\_decomp\decompositions.py:15
#      13 import torch
#      14 import torch._meta_registrations
# ---> 15 import torch._prims as prims
#      16 import torch._prims_common as utils
#      17 import torch.nn.functional as F
#
# File f:\project\python3.10.11\lib\site-packages\torch\_prims\__init__.py:36
#      32 from torch.overrides import handle_torch_function, has_torch_function
#      33 from torch.utils._pytree import tree_flatten, tree_map, tree_unflatten
# ---> 36 prim = torch.library.Library("prims", "DEF")
#      37 prim_impl = torch.library.Library("prims", "IMPL", "CompositeExplicitAutograd")
#      38 prim_backend_select_impl = torch.library.Library("prims", "IMPL", "BackendSelect")
#
# File f:\project\python3.10.11\lib\site-packages\torch\library.py:87, in Library.__init__(self, ns, kind, dispatch_key)
#      85 frame = traceback.extract_stack(limit=3)[0]
#      86 filename, lineno = frame.filename, frame.lineno
# ---> 87 self.m: Optional[Any] = torch._C._dispatch_library(
#      88     kind, ns, dispatch_key, filename, lineno
#      89 )
#      90 self.ns = ns
#      91 self._op_defs: Set[str] = set()
#
# RuntimeError: Only a single TORCH_LIBRARY can be used to register the namespace prims; please put all of your definitions in a single TORCH_LIBRARY block.  If you were trying to specify implementations, consider using TORCH_LIBRARY_IMPL (which can be duplicated).  If you really intended to define operators for a single namespace in a distributed way, you can use TORCH_LIBRARY_FRAGMENT to explicitly indicate this.  Previous registration of TORCH_LIBRARY was registered at /dev/null:241; latest registration was registered at /dev/null:241

# %% [markdown]
# 定义模型的输出函数

# %%
# 一个简单的推理函数
def get_outputs(model, inputs, max_new_tokens=100):
    outputs = model.generate(
        input_ids=inputs["input_ids"].to(model.device),
        attention_mask=inputs["attention_mask"].to(model.device),
        max_new_tokens=max_new_tokens,
        repetition_penalty=1.5, # 避免模型复读，默认值为1.0
        eos_token_id=tokenizer.eos_token_id
    )
    return outputs

# %% [markdown]
# 查看模型的输出

# %%
# 测试一下这个推理函数
input_sentences = tokenizer("I love this movie because", return_tensors="pt")
foundational_outputs_sentence = get_outputs(foundation_model, input_sentences, max_new_tokens=50)

print(tokenizer.batch_decode(foundational_outputs_sentence, skip_special_tokens=True))
# Out:
# ['I love this movie because it is so funny and I am sure that my friends will enjoy too']

# %% [markdown]
# 准备数据集

# %%
from datasets import load_dataset
dataset = "noob123/imdb_review_3000"
#Create the Dataset to create prompts.
data = load_dataset(dataset)

data = data.map(lambda samples: tokenizer(samples['review']), batched=True)
train_sample = data["train"].select(range(2000))

train_sample = train_sample.remove_columns('sentiment')

display(train_sample)
# Out:
# Dataset({
#     features: ['review', 'input_ids', 'attention_mask'],
#     num_rows: 2000
# })

# %% [markdown]
# 安装依赖

# %% [markdown]
# 可以简单看看数据集的一个小样本示例

# %%
print(train_sample[:1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(train_sample[:1])
#
# NameError: name 'train_sample' is not defined

# %% [markdown]
# 微调与训练

# %% [markdown]
# 首先加载Lora所需要用到的参数 `Config`

# %%
import peft
from peft import LoraConfig, get_peft_model, PeftModel

lora_config = LoraConfig(
    r=2, #As bigger the R bigger the parameters to train.
    lora_alpha=1, # a scaling factor that adjusts the magnitude of the weight matrix. Usually set to 1
    target_modules=["query_key_value"], #You can obtain a list of target modules in the URL above.
    lora_dropout=0.05, #Helps to avoid Overfitting.
    bias="lora_only", # this specifies if the bias parameter should be trained.
    task_type="CAUSAL_LM"
)

# %% [markdown]
# 使用上述 `lora_config` 包装模型

# %%
peft_model = get_peft_model(foundation_model, lora_config)
print(peft_model.print_trainable_parameters())
# Out:
# trainable params: 270,336 || all params: 559,411,200 || trainable%: 0.0483
# None

# %% [markdown]
# 创建工作区用于保存模型

# %%
import os
working_dir = './'

output_directory = os.path.join(working_dir, "peft_lab_outputs")

# %% [markdown]
# 设定训练参数

# %%
import transformers
from transformers import TrainingArguments, Trainer
training_args = TrainingArguments(
    output_dir=output_directory,
    auto_find_batch_size=True, # Find a correct bvatch size that fits the size of Data.
    learning_rate= 3e-2, # Higher learning rate than full fine-tuning.
    num_train_epochs=2,
    use_cpu=False
)

# %% [markdown]
# 启动训练

# %%
trainer = Trainer(
    model=peft_model,
    args=training_args,
    train_dataset=train_sample,
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
trainer.train()
# Out:
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       1 trainer = Trainer(
#       2     model=peft_model,
#       3     args=training_args,
#       4     train_dataset=train_sample,
#       5     data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
#       6 )
# ----> 7 trainer.train()
#
# File f:\project\python3.10.11\lib\site-packages\transformers\trainer.py:2245, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243         hf_hub_utils.enable_progress_bars()
#    2244 else:
# -> 2245     return inner_training_loop(
#    2246         args=args,
#    2247         resume_from_checkpoint=resume_from_checkpoint,
#    2248         trial=trial,
#    2249         ignore_keys_for_eval=ignore_keys_for_eval,
#    2250     )
#
# File f:\project\python3.10.11\lib\site-packages\accelerate\utils\memory.py:159, in find_executable_batch_size.<locals>.decorator(*args, **kwargs)
#     157     raise RuntimeError("No executable batch size found, reached zero.")
#     158 try:
# --> 159     return function(batch_size, *args, **kwargs)
#     160 except Exception as e:
#     161     if should_reduce_batch_size(e):
#
# File f:\project\python3.10.11\lib\site-packages\transformers\trainer.py:2560, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2553 context = (
#    2554     functools.partial(self.accelerator.no_sync, model=model)
#    2555     if i != len(batch_samples) - 1
#    2556     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2557     else contextlib.nullcontext
#    2558 )
#    2559 with context():
# -> 2560     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2562 if (
#    2563     args.logging_nan_inf_filter
#    2564     and not is_torch_xla_available()
#    2565     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2566 ):
#    2567     # if loss is nan or inf simply add the average of previous logged losses
#    2568     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File f:\project\python3.10.11\lib\site-packages\transformers\trainer.py:3736, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    3733     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3735 with self.compute_loss_context_manager():
# -> 3736     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3738 del inputs
#    3739 if (
#    3740     self.args.torch_empty_cache_steps is not None
#    3741     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    3742 ):
#
# File f:\project\python3.10.11\lib\site-packages\transformers\trainer.py:3801, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3799         loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3800     inputs = {**inputs, **loss_kwargs}
# -> 3801 outputs = model(**inputs)
#    3802 # Save past state if it exists
#    3803 # TODO: this needs to be fixed and made cleaner later.
#    3804 if self.args.past_index >= 0:
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File f:\project\python3.10.11\lib\site-packages\peft\peft_model.py:1719, in PeftModelForCausalLM.forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1717     with self._enable_peft_forward_hooks(**kwargs):
#    1718         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1719         return self.base_model(
#    1720             input_ids=input_ids,
#    1721             attention_mask=attention_mask,
#    1722             inputs_embeds=inputs_embeds,
#    1723             labels=labels,
#    1724             output_attentions=output_attentions,
#    1725             output_hidden_states=output_hidden_states,
#    1726             return_dict=return_dict,
#    1727             **kwargs,
#    1728         )
#    1730 batch_size = _get_batch_size(input_ids, inputs_embeds)
#    1731 if attention_mask is not None:
#    1732     # concat prompt attention mask
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File f:\project\python3.10.11\lib\site-packages\peft\tuners\tuners_utils.py:197, in BaseTuner.forward(self, *args, **kwargs)
#     196 def forward(self, *args: Any, **kwargs: Any):
# --> 197     return self.model.forward(*args, **kwargs)
#
# File f:\project\python3.10.11\lib\site-packages\transformers\models\bloom\modeling_bloom.py:1000, in BloomForCausalLM.forward(self, input_ids, past_key_values, attention_mask, head_mask, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **deprecated_arguments)
#     996     raise ValueError(f"Got unexpected arguments: {deprecated_arguments}")
#     998 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1000 transformer_outputs = self.transformer(
#    1001     input_ids,
#    1002     past_key_values=past_key_values,
#    1003     attention_mask=attention_mask,
#    1004     head_mask=head_mask,
#    1005     inputs_embeds=inputs_embeds,
#    1006     use_cache=use_cache,
#    1007     output_attentions=output_attentions,
#    1008     output_hidden_states=output_hidden_states,
#    1009     return_dict=return_dict,
#    1010     cache_position=cache_position,
#    1011 )
#    1012 hidden_states = transformer_outputs[0]
#    1014 lm_logits = self.lm_head(hidden_states)
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File f:\project\python3.10.11\lib\site-packages\transformers\models\bloom\modeling_bloom.py:702, in BloomModel.forward(self, input_ids, past_key_values, attention_mask, head_mask, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **deprecated_arguments)
#     690     outputs = self._gradient_checkpointing_func(
#     691         block.__call__,
#     692         hidden_states,
#    (...)
#     699         cache_position,
#     700     )
#     701 else:
# --> 702     outputs = block(
#     703         hidden_states,
#     704         layer_past=past_key_values,
#     705         attention_mask=causal_mask,
#     706         head_mask=head_mask[i],
#     707         use_cache=use_cache,
#     708         output_attentions=output_attentions,
#     709         alibi=alibi,
#     710         cache_position=cache_position,
#     711     )
#     713 hidden_states = outputs[0]
#     714 if use_cache:
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File f:\project\python3.10.11\lib\site-packages\transformers\models\bloom\modeling_bloom.py:426, in BloomBlock.forward(self, hidden_states, alibi, attention_mask, layer_past, head_mask, use_cache, output_attentions, cache_position)
#     422 attention_output = attn_outputs[0]
#     424 outputs = attn_outputs[1:]
# --> 426 layernorm_output = self.post_attention_layernorm(attention_output)
#     428 # Get residual
#     429 if self.apply_residual_connection_post_layernorm:
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\modules\normalization.py:217, in LayerNorm.forward(self, input)
#     216 def forward(self, input: Tensor) -> Tensor:
# --> 217     return F.layer_norm(
#     218         input, self.normalized_shape, self.weight, self.bias, self.eps
#     219     )
#
# File f:\project\python3.10.11\lib\site-packages\torch\nn\functional.py:2900, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2890 if has_torch_function_variadic(input, weight, bias):
#    2891     return handle_torch_function(
#    2892         layer_norm,
#    2893         (input, weight, bias),
#    (...)
#    2898         eps=eps,
#    2899     )
# -> 2900 return torch.layer_norm(
#    2901     input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2902 )
#
# KeyboardInterrupt:

# %% [markdown]
# 保存模型

# %%
peft_model_path = os.path.join(output_directory, f"lora_model")

trainer.model.save_pretrained(peft_model_path)

# %% [markdown]
# 加载模型并推理

# %%
loaded_model = PeftModel.from_pretrained(foundation_model, peft_model_path, is_trainable=False)
input_sentences = tokenizer("I love this movie because", return_tensors="pt")
foundational_outputs_sentence = get_outputs(loaded_model, input_sentences, max_new_tokens=100)

print(tokenizer.batch_decode(foundational_outputs_sentence, skip_special_tokens=True))
# Out:
# ["I love this movie because it is a very good film. The acting of the actors and their performances are excellent, but I would like to add that there was also an interesting storyline involving some strange characters in which they played roles as well (the main character being one who had been killed by aliens). This made me think about how much more fun could be given if we were able for us all just watching these films together instead!<br /><br />The only thing that's missing from my list today - or at least not yet"]
